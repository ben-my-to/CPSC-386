# %%
from collections import namedtuple
from random import shuffle

# %%
Card = namedtuple('Card', ['rank', 'suit'])

def stringify_card(c):
    return '{} of {}'.format(c.rank, c.suit)

Card.__str__ = stringify_card

# %%
class Deck:
    ranks = ['Ace'] + list(map(str, range(2, 11))) + \
        'Jack Queen King'.split()

    suits = 'Clubs Hearts Spades Diamonds'.split()
    
    values = list(range(1, 11)) + [10, 10, 10]

    def __init__(self):
        self._cards = [Card(rank, suit)      \
            for suit in Deck.suits           \
            for rank in Deck.ranks]

    def __str__(self):
        return '\n'.join(['{} {}'.format(i, j) \
            for i , j in enumerate(self._cards)])

    def __len__(self):
        return len(self._cards)

    def shuffle(self, n=1):
        for i in range(n):
            shuffle(self._cards)

    def deal(self, n=1):
        return [self._cards.pop() for i in range(n)]

# %%
c = Card('3', 'Diamonds')

"""
print(ranks)
print(suits)
print(c)
print(str(c))
print('\n'.join(map(str, cards)))
"""

d = Deck()
d.shuffle(3)

print(d)

value_dict = dict(zip(Deck.ranks, Deck.values))
print(value_dict['Queen'])

hand = d.deal(7)
print(hand)
print(d)
# Out:
# 0 6 of Hearts
# 1 7 of Hearts
# 2 Ace of Diamonds
# 3 4 of Spades
# 4 King of Hearts
# 5 8 of Diamonds
# 6 5 of Diamonds
# 7 8 of Spades
# 8 Jack of Clubs
# 9 Queen of Hearts
# 10 2 of Hearts
# 11 5 of Spades
# 12 Queen of Diamonds
# 13 10 of Diamonds
# 14 3 of Spades
# 15 4 of Diamonds
# 16 9 of Diamonds
# 17 King of Clubs
# 18 4 of Hearts
# 19 7 of Spades
# 20 King of Diamonds
# 21 10 of Spades
# 22 Jack of Hearts
# 23 5 of Hearts
# 24 6 of Spades
# 25 King of Spades
# 26 3 of Diamonds
# 27 Ace of Hearts
# 28 Jack of Spades
# 29 5 of Clubs
# 30 6 of Clubs
# 31 6 of Diamonds
# 32 2 of Clubs
# 33 10 of Clubs
# 34 Ace of Clubs
# 35 7 of Clubs
# 36 4 of Clubs
# 37 8 of Clubs
# 38 3 of Hearts
# 39 10 of Hearts
# 40 9 of Spades
# 41 2 of Diamonds
# 42 2 of Spades
# 43 Ace of Spades
# 44 Jack of Diamonds
# 45 8 of Hearts
# 46 7 of Diamonds
# 47 Queen of Spades
# 48 9 of Hearts
# 49 Queen of Clubs
# 50 3 of Clubs
# 51 9 of Clubs
# 10
# [Card(rank='9', suit='Clubs'), Card(rank='3', suit='Clubs'), Card(rank='Queen', suit='Clubs'), Card(rank='9', suit='Hearts'), Card(rank='Queen', suit='Spades'), Card(rank='7', suit='Diamonds'), Card(rank='8', suit='Hearts')]
# 0 6 of Hearts
# 1 7 of Hearts
# 2 Ace of Diamonds
# 3 4 of Spades
# 4 King of Hearts
# 5 8 of Diamonds
# 6 5 of Diamonds
# 7 8 of Spades
# 8 Jack of Clubs
# 9 Queen of Hearts
# 10 2 of Hearts
# 11 5 of Spades
# 12 Queen of Diamonds
# 13 10 of Diamonds
# 14 3 of Spades
# 15 4 of Diamonds
# 16 9 of Diamonds
# 17 King of Clubs
# 18 4 of Hearts
# 19 7 of Spades
# 20 King of Diamonds
# 21 10 of Spades
# 22 Jack of Hearts
# 23 5 of Hearts
# 24 6 of Spades
# 25 King of Spades
# 26 3 of Diamonds
# 27 Ace of Hearts
# 28 Jack of Spades
# 29 5 of Clubs
# 30 6 of Clubs
# 31 6 of Diamonds
# 32 2 of Clubs
# 33 10 of Clubs
# 34 Ace of Clubs
# 35 7 of Clubs
# 36 4 of Clubs
# 37 8 of Clubs
# 38 3 of Hearts
# 39 10 of Hearts
# 40 9 of Spades
# 41 2 of Diamonds
# 42 2 of Spades
# 43 Ace of Spades
# 44 Jack of Diamonds
